# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import random
import matplotlib.pyplot as plt

# %matplotlib inline

# !ls
# %mkdir data
# !ls
# Out:
# data  drive  sample_data
# mkdir: cannot create directory ‘data’: File exists
# data  drive  sample_data

# %%
from sklearn.metrics import accuracy_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil
shutil.copy("/content/drive/MyDrive/sis_420/lab_repaso/03_redes_neur_mnist/train.csv","/content/data/train.csv")
# Out:
# '/content/data/train.csv'

# %%
data = pd.read_csv( os.path.join('data', 'train.csv') )
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68161 entries, 0 to 68160
# Columns: 785 entries, label to pixel784
# dtypes: float64(784), int64(1)
# memory usage: 408.2 MB

# %%
X = data.iloc[:, 1:].values
Y = data.iloc[:, 0].values

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-b6010b7ef948> in <cell line: 1>()
# ----> 1 Y.info()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'info'
